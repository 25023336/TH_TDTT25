# %%
#W6A1
#Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng giữ nguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả.
#Yêu cầu in ra đúng dạng list Python, ví dụ [1, 2, 3]
A = list(map(int,input().split()))
S = []
for i in A:
    if i not in S:
        S.append(i)
print(S)
# Out:
#  1 2 2 3 1 4
# [1, 2, 3, 4]

# %%
#W6A2
#Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu tới vị trí i), giữ nguyên thứ tự
A = list(map(int,input().split()))
S = []
sum = 0
for x in A:
    sum += x
    S.append(sum)
print(S)
# Out:
#  1 2 3 4
# [1, 3, 6, 10]

# %%
#W6A3
#Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kế). In ra tuple sau khi xoay trái k vị trí
#(Giữ nguyên thứ tự tương đối sau xoay; không sắp xếp.)
A = tuple(map(int,input().split()))
k = int(input())
k = k % len(A)
A_rotated = A[k:] + A[k:]
print(A_rotated)
# Out:
#  1 2 3 4 5
#  2
# (3, 4, 5, 3, 4, 5)

# %%
#W6A4
#Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo dictionary ánh xạ mỗi key 
#-> list các value theo thứ tự xuất hiện. Nếu key lặp lại, thêm vào list của key 
s = input().strip().split()
d = {}
for pair in s:
    key,value = pair.split(':')
    if key not in d:
        d[key] = []
    d[key].append(int(value))
print(d)
# Out:
#  a:1 b:2 c:3
# {'a': [1], 'b': [2], 'c': [3]}

# %%
tuple_repeat = ('repeat',) * 3
tuple_repeat
# Out:
# ('repeat', 'repeat', 'repeat')

# %%
t = (1,2,[3,4])
#t[0] = 0
t[2][0] = 1
t
# Out:
# (1, 2, [1, 4])

# %%
tup = (1,2,3,4,5)
a, *b, c = tup
print(a)
print(b)
print(c)
# Out:
# 1
# [2, 3, 4]
# 5

# %%
tuple (x for x in range(5))
# Out:
# (0, 1, 2, 3, 4)

# %%
tuple(map(lambda x: x*x,[1,2,3]))
# Out:
# (1, 4, 9)

# %%
#W6A5
lst = list(map(int,input().split()))
pos = 0
neg = 0
zeros = 0
for x in lst:
    if x > 0:
        pos += 1
    elif x < 0:
        neg += 1
    else:
        zeros += 1
print({'positive':pos,'negatives':neg,'zeros':zeros})
# Out:
#  1 2 3 4 5 0 -4 -2 -5 1 3 0
# {'positive': 7, 'negatives': 3, 'zeros': 2}

# %%
#W6A8
lst = input().split()
count_dict = {}

for s in lst:
    if s not in count_dict:
        count_dict[s] = 1
    else:
        count_dict[s] += 1

print(count_dict)
# Out:
#  apple banana apple
# {'apple': 2, 'banana': 1}

# %%
#W6A7
t = tuple(input().split())
print(t[0])
print(t[-1])
print(t[::-1])
# Out:
#  5 8 2 7 1 4
# 5
# 4
# ('4', '1', '7', '2', '8', '5')

# %%
#W6A6
lst = list(map(int,input().split()))
sum = 0
for i in lst: 
    sum += i
print(sum)
# Out:
#  1 2 3 4
# 10

# %%
#W6A13
a = input().split()

dict = {}

dict = {a[i+1]:a[i] for i in range (0,len(a),2)}
print(dict)
# Out:
#  a 1 b 2 c 3
# {'1': 'a', '2': 'b', '3': 'c'}

# %%
#W6A9
dict1 = eval(input())
dict2 = eval(input())
result = {}

for k, v in dict1.items():
    result[k] = v
for k, v in dict2.items():
    if k in result:
        result[k] += v
    else:
        result[k] = v

for k in sorted(result):
    print(k, result[k])
# Out:
#  {a:1}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 #W6A9
# ----> 2 dict1 = eval(input())
#       3 dict2 = eval(input())
#       4 result = {}
#
# File <string>:1
#
# TypeError: unhashable type: 'list'
