# %%
#W4A1
n=int(input('Nhap so nguyen n:'))
S=0
if n>1000: print('Nhap lai')
else:
    for i in range(1,n+1):
        S=S+i
    print(S)
# Out:
# Nhap so nguyen n: 125
# 7875

# %%
#W4A2
n=0
for _ in range(10000): #Khong can i
    n=int(input('Nhap so n'))
    if(n>0):
        break
    else:
        continue
        print('Ban phai nhap lai n')
print('So nguyen duong ban nhap duoc la:',n)
# Out:
# Nhap so n 1234
# So nguyen duong ban nhap duoc la: 1234

# %%
#W4A3
try: 
    n=int(input('Nhap so nguyen n'))
    ngt=1
    for i in range(1,n+1):
        ngt=ngt*i
    print('Giai thua cua',n,'la:',ngt)
except ValueError:
    print('Nhap du lieu sai')
# Out:
# Nhap so nguyen n 10
# Giai thua cua 10 la: 3628800

# %%
#W4A2
x = int(input(''))
goal = 1
while x != 1:
    goal *= x
    x -= 1
print(goal)
# Out:
#  5
# 120

# %%
#W4A1
sum = 0
i = 1
while i <= 1000:
    sum += i
print(sum)

# %%
#W4A4
n = int(input(""))
n = abs(n)
x = 0
while n != 0:
    x += 1
    n //= 10
print(x)
# Out:
#  3
# 1

# %%
#W4A11
n = int(input(""))
a = 0
b = 0
while a <n:
    if a %2==0:
        b+=1
    a+=1
print(b)
