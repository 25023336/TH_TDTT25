# %%
#W5A1
a = int(input(""))
b = int(input(""))
print(max(a,b))
# Out:
#  2
#  5
# 5

# %%
#W5A2
def swap(x,y):
    return [y,x]

a = int(input(""))
b = int(input(""))
print(a,b)
a,b = swap(a,b)
print(a,b)
# Out:
#  4
#  7
# 4 7
# 7 4

# %%
#W5A4
def perfect(x):
    sum = 0
    for i in range(1,x//2+1):
        if x%i == 0:
            sum+=i
    return sum == i

x = int(input(""))
if perfect(x):
    print("Yes")
else:
    print("No")
# Out:
#  5
# No

# %%
#W5A6
def gt(a):
    if a == 1:
        return 1
    return a*gt(a-1)

print(gt(5))
# Out:
# 120

# %%
#W5A8
a,b = list(map(int,input().split()))
print(bin(a^b).count('1'))
# Out:
#  1010 1001
# 4

# %%
#W5A9
n = int(input(""))
s = 0
while n > 0:
    s += n % 10
    n //= 10
print(s)
# Out:
#  1023
# 6
